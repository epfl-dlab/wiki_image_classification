# %%
import pandas as pd
from configs import configs
config = configs[0]

# %%
probs = pd.read_json('results_paper/probs_df_010523.json.bz2')

# %%
probs.head()
# Out:
#     Animals  Architecture       Art  Chemistry   Culture  Diagrams    Events  \
# 0  0.735937      0.610440  0.695302   0.786517  0.514223  0.787173  0.398747
# 1  0.453368      0.651396  0.332550   0.887171  0.498168  0.947294  0.352541
# 2  0.657097      0.477013  0.606726   0.586477  0.638371  0.717073  0.665569
# 3  0.503465      0.765135  0.854786   0.903884  0.545337  0.725359  0.483671
# 4  0.346457      0.488528  0.389400   0.724322  0.291549  0.650406  0.585479
#
#        Food  Geology & Fossils   History  ...    People    Places    Plants  \
# 0  0.487006           0.496861  0.458899  ...  0.398931  0.536407  0.525019
# 1  0.300119           0.397797  0.241857  ...  0.252839  0.653084  0.653059
# 2  0.435259           0.410702  0.658064  ...  0.131231  0.622671  0.224300
# 3  0.546941           0.423546  0.496269  ...  0.473934  0.187073  0.433518
# 4  0.584318           0.448367  0.394667  ...  0.271164  0.489913  0.323199
#
# ...
